# %%
import pandas as pd
from scipy import stats
import plotly.express as px

# %%
df = pd.read_csv('../data/ab_testing/fast_food.csv')
df.head()
# Out:
#    MarketID MarketSize  LocationID  AgeOfStore  Promotion  week  \
# 0         1     Medium           1           4          3     1
# 1         1     Medium           1           4          3     2
# 2         1     Medium           1           4          3     3
# 3         1     Medium           1           4          3     4
# 4         1     Medium           2           5          2     1
#
#    SalesInThousands
# 0             33.73
# 1             35.67
# 2             29.03
# 3             39.25
# 4             27.81

# %%
df.describe()
# Out:
#          MarketID  LocationID  AgeOfStore   Promotion        week  \
# count  548.000000  548.000000  548.000000  548.000000  548.000000
# mean     5.715328  479.656934    8.503650    2.029197    2.500000
# std      2.877001  287.973679    6.638345    0.810729    1.119055
# min      1.000000    1.000000    1.000000    1.000000    1.000000
# 25%      3.000000  216.000000    4.000000    1.000000    1.750000
# 50%      6.000000  504.000000    7.000000    2.000000    2.500000
# 75%      8.000000  708.000000   12.000000    3.000000    3.250000
# max     10.000000  920.000000   28.000000    3.000000    4.000000
#
#        SalesInThousands
# count        548.000000
# mean          53.466204
# std           16.755216
# min           17.340000
# 25%           42.545000
# 50%           50.200000
# 75%           60.477500
# max           99.650000

# %%
df['MarketSize'].value_counts()
# Out:
# MarketSize
# Medium    320
# Large     168
# Small      60
# Name: count, dtype: int64

# %%
df['MarketSize'].value_counts()
# Out:
# MarketSize
# Medium    320
# Large     168
# Small      60
# Name: count, dtype: int64

# %%
fig = px.box(
    df,
    x = "Promotion",
    y = "SalesInThousands",
    color = "Promotion",
    title = "Sales Distribution by Promotion" 
)

fig

# %%
weekly_sales = (
    df.groupby(["week","Promotion"])['SalesInThousands'].mean().reset_index()
)

# %%
weekly_sales.head()
# Out:
#    week  Promotion  SalesInThousands
# 0     1          1         58.244419
# 1     1          2         47.730213
# 2     1          3         55.776170
# 3     2          1         56.929535
# 4     2          2         47.582553

# %%
px.box(
    data_frame = df,
    x = 'MarketSize',
    y = "SalesInThousands",
    color = "Promotion",
    title = "Sales By MartetSize per Promotion"

)
